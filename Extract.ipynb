# %%
import moviepy.editor as mp

# Load the video file
video = mp.VideoFileClip("/content/drive/MyDrive/ICIPE Research/Video_analytics/Videos/VID_20240202_100227.mp4")

# Get the duration of the video in seconds
duration = video.duration

# Calculate the number of clips to create
num_clips = int(duration / 60)

# Create a list to store the clips
clips = []

# Iterate over the number of clips
for i in range(num_clips):

    # Calculate the start and end times of the clip
    start_time = i * 60
    end_time = (i + 1) * 60

    # Create a clip from the video
    clip = video.subclip(start_time, end_time)

    # Add the clip to the list
    clips.append(clip)

# Save each clip to a separate file
for i, clip in enumerate(clips):

    # Create a filename for the clip
    filename = "clip_{}.mp4".format(i)

    # Save the clip to the file
    clip.write_videofile(filename)

# %%
import moviepy.editor as mpe

# Define the input video file
input_video = "/content/drive/MyDrive/ICIPE Research/Video_analytics/Videos/VID_20240202_100227.mp4"

# Define the output directory
output_dir = "/content/drive/MyDrive/ICIPE Research/Video_analytics/Videos/clips"

# Load the video file
video = mpe.VideoFileClip(input_video)

# Calculate the duration of each clip
clip_duration = 60  # in seconds

# Split the video into clips
clips = [video.subclip(start, start + clip_duration) for start in range(0, video.duration, clip_duration)]

# Save each clip to the output directory
for i, clip in enumerate(clips):
    output_path = f"{output_dir}/clip_{i}.mp4"
    clip.write_videofile(output_path)

# Print a success message
print("Video clips successfully created and saved to the output directory.")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-1-30fd954e0c88> in <cell line: 16>()
#      14
#      15 # Split the video into clips
# ---> 16 clips = [video.subclip(start, start + clip_duration) for start in range(0, video.duration, clip_duration)]
#      17
#      18 # Save each clip to the output directory
#
# TypeError: 'float' object cannot be interpreted as an integer

# %%
import moviepy.editor as mpe

# Define the input video file
input_video = "larvae.mp4"

# Define the output directory
output_dir = "/content/drive/MyDrive/ICIPE Research/Video_analytics/Videos/clips"

# Load the video file
video = mpe.VideoFileClip(input_video)

# Define the clip duration in seconds
clip_duration = 60

# Calculate the number of clips
num_clips = int(video.duration / clip_duration)

# Create a list of clips
clips = [video.subclip(start, start + clip_duration) for start in range(0, video.duration, clip_duration)]

# Save each clip to the output directory
for i, clip in enumerate(clips):
    clip.write_videofile(f"{output_dir}/clip_{i + 1}.mp4")

# Print a success message
print("Clips successfully created and saved to the output directory.")

# %%
import os
import cv2

def extract_clips(input_folder, output_folder, clip_length=100):
    # Create the output folder if it doesn't exist
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    # Loop through each file in the input folder
    for filename in os.listdir(input_folder):
        # Check if the file is a video
        if filename.endswith(('.mp4', '.avi', '.mov')):
            filepath = os.path.join(input_folder, filename)
            cap = cv2.VideoCapture(filepath)
            frame_count = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
            if frame_count < clip_length:
                print(f"Skipping {filename} - Insufficient frames")
                continue

            # Extract clips
            clip_count = frame_count // clip_length
            for i in range(clip_count):
                start_frame = i * clip_length
                end_frame = min(start_frame + clip_length, frame_count)

                cap.set(cv2.CAP_PROP_POS_FRAMES, start_frame)
                clip_frames = []
                for _ in range(start_frame, end_frame):
                    ret, frame = cap.read()
                    if ret:
                        clip_frames.append(frame)
                    else:
                        break

                # Save the clip
                output_filename = f"{filename}_clip_{i}.avi"
                output_filepath = os.path.join(output_folder, output_filename)
                out = cv2.VideoWriter(output_filepath, cv2.VideoWriter_fourcc(*'DIVX'), cap.get(cv2.CAP_PROP_FPS), (frame.shape[1], frame.shape[0]))
                for frame in clip_frames:
                    out.write(frame)
                out.release()

            cap.release()

# Example usage
input_folder = "/content/drive/MyDrive/ICIPE Research/Video_analytics/Videos/Negative"
output_folder = "/content/drive/MyDrive/ICIPE Research/Video_analytics/Videos/Negative_Data/100_frames"
extract_clips(input_folder, output_folder)

# %%
import os
import cv2

def extract_clips(input_folder, output_folder, clip_length=200):
    # Create the output folder if it doesn't exist
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    # Loop through each file in the input folder
    for filename in os.listdir(input_folder):
        # Check if the file is a video
        if filename.endswith(('.mp4', '.avi', '.mov')):
            filepath = os.path.join(input_folder, filename)
            cap = cv2.VideoCapture(filepath)
            frame_count = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
            if frame_count < clip_length:
                print(f"Skipping {filename} - Insufficient frames")
                continue

            # Extract clips
            clip_count = frame_count // clip_length
            for i in range(clip_count):
                start_frame = i * clip_length
                end_frame = min(start_frame + clip_length, frame_count)

                cap.set(cv2.CAP_PROP_POS_FRAMES, start_frame)
                clip_frames = []
                for _ in range(start_frame, end_frame):
                    ret, frame = cap.read()
                    if ret:
                        clip_frames.append(frame)
                    else:
                        break

                # Save the clip
                output_filename = f"{filename}_clip_{i}.avi"
                output_filepath = os.path.join(output_folder, output_filename)
                out = cv2.VideoWriter(output_filepath, cv2.VideoWriter_fourcc(*'DIVX'), cap.get(cv2.CAP_PROP_FPS), (frame.shape[1], frame.shape[0]))
                for frame in clip_frames:
                    out.write(frame)
                out.release()

            cap.release()

# Example usage
input_folder = "/content/drive/MyDrive/ICIPE Research/Video_analytics/Videos/Negative"
output_folder = "/content/drive/MyDrive/ICIPE Research/Video_analytics/Videos/Negative_Data/200_frames"
extract_clips(input_folder, output_folder)

# %%
import os
import cv2

def extract_clips(input_folder, output_folder, clip_length=300):
    # Create the output folder if it doesn't exist
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    # Loop through each file in the input folder
    for filename in os.listdir(input_folder):
        # Check if the file is a video
        if filename.endswith(('.mp4', '.avi', '.mov')):
            filepath = os.path.join(input_folder, filename)
            cap = cv2.VideoCapture(filepath)
            frame_count = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
            if frame_count < clip_length:
                print(f"Skipping {filename} - Insufficient frames")
                continue

            # Extract clips
            clip_count = frame_count // clip_length
            for i in range(clip_count):
                start_frame = i * clip_length
                end_frame = min(start_frame + clip_length, frame_count)

                cap.set(cv2.CAP_PROP_POS_FRAMES, start_frame)
                clip_frames = []
                for _ in range(start_frame, end_frame):
                    ret, frame = cap.read()
                    if ret:
                        clip_frames.append(frame)
                    else:
                        break

                # Save the clip
                output_filename = f"{filename}_clip_{i}.avi"
                output_filepath = os.path.join(output_folder, output_filename)
                out = cv2.VideoWriter(output_filepath, cv2.VideoWriter_fourcc(*'DIVX'), cap.get(cv2.CAP_PROP_FPS), (frame.shape[1], frame.shape[0]))
                for frame in clip_frames:
                    out.write(frame)
                out.release()

            cap.release()

# Example usage
input_folder = "/content/drive/MyDrive/ICIPE Research/Video_analytics/Videos/Negative"
output_folder = "/content/drive/MyDrive/ICIPE Research/Video_analytics/Videos/Negative_Data/300_frames"
extract_clips(input_folder, output_folder)

# %%
import os
import cv2

def extract_clips(input_folder, output_folder, clip_length=400):
    # Create the output folder if it doesn't exist
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    # Loop through each file in the input folder
    for filename in os.listdir(input_folder):
        # Check if the file is a video
        if filename.endswith(('.mp4', '.avi', '.mov')):
            filepath = os.path.join(input_folder, filename)
            cap = cv2.VideoCapture(filepath)
            frame_count = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
            if frame_count < clip_length:
                print(f"Skipping {filename} - Insufficient frames")
                continue

            # Extract clips
            clip_count = frame_count // clip_length
            for i in range(clip_count):
                start_frame = i * clip_length
                end_frame = min(start_frame + clip_length, frame_count)

                cap.set(cv2.CAP_PROP_POS_FRAMES, start_frame)
                clip_frames = []
                for _ in range(start_frame, end_frame):
                    ret, frame = cap.read()
                    if ret:
                        clip_frames.append(frame)
                    else:
                        break

                # Save the clip
                output_filename = f"{filename}_clip_{i}.avi"
                output_filepath = os.path.join(output_folder, output_filename)
                out = cv2.VideoWriter(output_filepath, cv2.VideoWriter_fourcc(*'DIVX'), cap.get(cv2.CAP_PROP_FPS), (frame.shape[1], frame.shape[0]))
                for frame in clip_frames:
                    out.write(frame)
                out.release()

            cap.release()

# Example usage
input_folder = "/content/drive/MyDrive/ICIPE Research/Video_analytics/Videos/Negative"
output_folder = "/content/drive/MyDrive/ICIPE Research/Video_analytics/Videos/Negative_Data/400_frames"
extract_clips(input_folder, output_folder)

# %%
import os
import cv2

def extract_clips(input_folder, output_folder, clip_length=500):
    # Create the output folder if it doesn't exist
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    # Loop through each file in the input folder
    for filename in os.listdir(input_folder):
        # Check if the file is a video
        if filename.endswith(('.mp4', '.avi', '.mov')):
            filepath = os.path.join(input_folder, filename)
            cap = cv2.VideoCapture(filepath)
            frame_count = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
            if frame_count < clip_length:
                print(f"Skipping {filename} - Insufficient frames")
                continue

            # Extract clips
            clip_count = frame_count // clip_length
            for i in range(clip_count):
                start_frame = i * clip_length
                end_frame = min(start_frame + clip_length, frame_count)

                cap.set(cv2.CAP_PROP_POS_FRAMES, start_frame)
                clip_frames = []
                for _ in range(start_frame, end_frame):
                    ret, frame = cap.read()
                    if ret:
                        clip_frames.append(frame)
                    else:
                        break

                # Save the clip
                output_filename = f"{filename}_clip_{i}.avi"
                output_filepath = os.path.join(output_folder, output_filename)
                out = cv2.VideoWriter(output_filepath, cv2.VideoWriter_fourcc(*'DIVX'), cap.get(cv2.CAP_PROP_FPS), (frame.shape[1], frame.shape[0]))
                for frame in clip_frames:
                    out.write(frame)
                out.release()

            cap.release()

# Example usage
input_folder = "/content/drive/MyDrive/ICIPE Research/Video_analytics/Videos/Negative"
output_folder = "/content/drive/MyDrive/ICIPE Research/Video_analytics/Videos/Negative_Data/500_frames"
extract_clips(input_folder, output_folder)

# %%
import os
import cv2

def extract_clips(input_folder, output_folder, clip_length=600):
    # Create the output folder if it doesn't exist
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    # Loop through each file in the input folder
    for filename in os.listdir(input_folder):
        # Check if the file is a video
        if filename.endswith(('.mp4', '.avi', '.mov')):
            filepath = os.path.join(input_folder, filename)
            cap = cv2.VideoCapture(filepath)
            frame_count = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
            if frame_count < clip_length:
                print(f"Skipping {filename} - Insufficient frames")
                continue

            # Extract clips
            clip_count = frame_count // clip_length
            for i in range(clip_count):
                start_frame = i * clip_length
                end_frame = min(start_frame + clip_length, frame_count)

                cap.set(cv2.CAP_PROP_POS_FRAMES, start_frame)
                clip_frames = []
                for _ in range(start_frame, end_frame):
                    ret, frame = cap.read()
                    if ret:
                        clip_frames.append(frame)
                    else:
                        break

                # Save the clip
                output_filename = f"{filename}_clip_{i}.avi"
                output_filepath = os.path.join(output_folder, output_filename)
                out = cv2.VideoWriter(output_filepath, cv2.VideoWriter_fourcc(*'DIVX'), cap.get(cv2.CAP_PROP_FPS), (frame.shape[1], frame.shape[0]))
                for frame in clip_frames:
                    out.write(frame)
                out.release()

            cap.release()

# Example usage
input_folder = "/content/drive/MyDrive/ICIPE Research/Video_analytics/Videos/Negative"
output_folder = "/content/drive/MyDrive/ICIPE Research/Video_analytics/Videos/Negative_Data/600_frames"
extract_clips(input_folder, output_folder)

# %%
import os
import cv2

def extract_clips(input_folder, output_folder, clip_length=700):
    # Create the output folder if it doesn't exist
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    # Loop through each file in the input folder
    for filename in os.listdir(input_folder):
        # Check if the file is a video
        if filename.endswith(('.mp4', '.avi', '.mov')):
            filepath = os.path.join(input_folder, filename)
            cap = cv2.VideoCapture(filepath)
            frame_count = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
            if frame_count < clip_length:
                print(f"Skipping {filename} - Insufficient frames")
                continue

            # Extract clips
            clip_count = frame_count // clip_length
            for i in range(clip_count):
                start_frame = i * clip_length
                end_frame = min(start_frame + clip_length, frame_count)

                cap.set(cv2.CAP_PROP_POS_FRAMES, start_frame)
                clip_frames = []
                for _ in range(start_frame, end_frame):
                    ret, frame = cap.read()
                    if ret:
                        clip_frames.append(frame)
                    else:
                        break

                # Save the clip
                output_filename = f"{filename}_clip_{i}.avi"
                output_filepath = os.path.join(output_folder, output_filename)
                out = cv2.VideoWriter(output_filepath, cv2.VideoWriter_fourcc(*'DIVX'), cap.get(cv2.CAP_PROP_FPS), (frame.shape[1], frame.shape[0]))
                for frame in clip_frames:
                    out.write(frame)
                out.release()

            cap.release()

# Example usage
input_folder = "/content/drive/MyDrive/ICIPE Research/Video_analytics/Videos/Negative"
output_folder = "/content/drive/MyDrive/ICIPE Research/Video_analytics/Videos/Negative_Data/700_frames"
extract_clips(input_folder, output_folder)

# %%
import os
import cv2

def extract_clips(input_folder, output_folder, clip_length=800):
    # Create the output folder if it doesn't exist
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    # Loop through each file in the input folder
    for filename in os.listdir(input_folder):
        # Check if the file is a video
        if filename.endswith(('.mp4', '.avi', '.mov')):
            filepath = os.path.join(input_folder, filename)
            cap = cv2.VideoCapture(filepath)
            frame_count = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
            if frame_count < clip_length:
                print(f"Skipping {filename} - Insufficient frames")
                continue

            # Extract clips
            clip_count = frame_count // clip_length
            for i in range(clip_count):
                start_frame = i * clip_length
                end_frame = min(start_frame + clip_length, frame_count)

                cap.set(cv2.CAP_PROP_POS_FRAMES, start_frame)
                clip_frames = []
                for _ in range(start_frame, end_frame):
                    ret, frame = cap.read()
                    if ret:
                        clip_frames.append(frame)
                    else:
                        break

                # Save the clip
                output_filename = f"{filename}_clip_{i}.avi"
                output_filepath = os.path.join(output_folder, output_filename)
                out = cv2.VideoWriter(output_filepath, cv2.VideoWriter_fourcc(*'DIVX'), cap.get(cv2.CAP_PROP_FPS), (frame.shape[1], frame.shape[0]))
                for frame in clip_frames:
                    out.write(frame)
                out.release()

            cap.release()

# Example usage
input_folder = "/content/drive/MyDrive/ICIPE Research/Video_analytics/Videos/Negative"
output_folder = "/content/drive/MyDrive/ICIPE Research/Video_analytics/Videos/Negative_Data/800_frames"
extract_clips(input_folder, output_folder)

# %%
import os
import cv2

def extract_clips(input_folder, output_folder, clip_length=900):
    # Create the output folder if it doesn't exist
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    # Loop through each file in the input folder
    for filename in os.listdir(input_folder):
        # Check if the file is a video
        if filename.endswith(('.mp4', '.avi', '.mov')):
            filepath = os.path.join(input_folder, filename)
            cap = cv2.VideoCapture(filepath)
            frame_count = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
            if frame_count < clip_length:
                print(f"Skipping {filename} - Insufficient frames")
                continue

            # Extract clips
            clip_count = frame_count // clip_length
            for i in range(clip_count):
                start_frame = i * clip_length
                end_frame = min(start_frame + clip_length, frame_count)

                cap.set(cv2.CAP_PROP_POS_FRAMES, start_frame)
                clip_frames = []
                for _ in range(start_frame, end_frame):
                    ret, frame = cap.read()
                    if ret:
                        clip_frames.append(frame)
                    else:
                        break

                # Save the clip
                output_filename = f"{filename}_clip_{i}.avi"
                output_filepath = os.path.join(output_folder, output_filename)
                out = cv2.VideoWriter(output_filepath, cv2.VideoWriter_fourcc(*'DIVX'), cap.get(cv2.CAP_PROP_FPS), (frame.shape[1], frame.shape[0]))
                for frame in clip_frames:
                    out.write(frame)
                out.release()

            cap.release()

# Example usage
input_folder = "/content/drive/MyDrive/ICIPE Research/Video_analytics/Videos/Negative"
output_folder = "/content/drive/MyDrive/ICIPE Research/Video_analytics/Videos/Negative_Data/900_frames"
extract_clips(input_folder, output_folder)

# %%
import os
import cv2

def extract_clips(input_folder, output_folder, clip_length=1000):
    # Create the output folder if it doesn't exist
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    # Loop through each file in the input folder
    for filename in os.listdir(input_folder):
        # Check if the file is a video
        if filename.endswith(('.mp4', '.avi', '.mov')):
            filepath = os.path.join(input_folder, filename)
            cap = cv2.VideoCapture(filepath)
            frame_count = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
            if frame_count < clip_length:
                print(f"Skipping {filename} - Insufficient frames")
                continue

            # Extract clips
            clip_count = frame_count // clip_length
            for i in range(clip_count):
                start_frame = i * clip_length
                end_frame = min(start_frame + clip_length, frame_count)

                cap.set(cv2.CAP_PROP_POS_FRAMES, start_frame)
                clip_frames = []
                for _ in range(start_frame, end_frame):
                    ret, frame = cap.read()
                    if ret:
                        clip_frames.append(frame)
                    else:
                        break

                # Save the clip
                output_filename = f"{filename}_clip_{i}.avi"
                output_filepath = os.path.join(output_folder, output_filename)
                out = cv2.VideoWriter(output_filepath, cv2.VideoWriter_fourcc(*'DIVX'), cap.get(cv2.CAP_PROP_FPS), (frame.shape[1], frame.shape[0]))
                for frame in clip_frames:
                    out.write(frame)
                out.release()

            cap.release()

# Example usage
input_folder = "/content/drive/MyDrive/ICIPE Research/Video_analytics/Videos/Negative"
output_folder = "/content/drive/MyDrive/ICIPE Research/Video_analytics/Videos/Negative_Data/1000_frames"
extract_clips(input_folder, output_folder)

# %%
import os
import cv2

def extract_clips(input_folder, output_folder, clip_length=1100):
    # Create the output folder if it doesn't exist
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    # Loop through each file in the input folder
    for filename in os.listdir(input_folder):
        # Check if the file is a video
        if filename.endswith(('.mp4', '.avi', '.mov')):
            filepath = os.path.join(input_folder, filename)
            cap = cv2.VideoCapture(filepath)
            frame_count = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
            if frame_count < clip_length:
                print(f"Skipping {filename} - Insufficient frames")
                continue

            # Extract clips
            clip_count = frame_count // clip_length
            for i in range(clip_count):
                start_frame = i * clip_length
                end_frame = min(start_frame + clip_length, frame_count)

                cap.set(cv2.CAP_PROP_POS_FRAMES, start_frame)
                clip_frames = []
                for _ in range(start_frame, end_frame):
                    ret, frame = cap.read()
                    if ret:
                        clip_frames.append(frame)
                    else:
                        break

                # Save the clip
                output_filename = f"{filename}_clip_{i}.avi"
                output_filepath = os.path.join(output_folder, output_filename)
                out = cv2.VideoWriter(output_filepath, cv2.VideoWriter_fourcc(*'DIVX'), cap.get(cv2.CAP_PROP_FPS), (frame.shape[1], frame.shape[0]))
                for frame in clip_frames:
                    out.write(frame)
                out.release()

            cap.release()

# Example usage
input_folder = "/content/drive/MyDrive/ICIPE Research/Video_analytics/Videos/Negative"
output_folder = "/content/drive/MyDrive/ICIPE Research/Video_analytics/Videos/Negative_Data/1100_frames"
extract_clips(input_folder, output_folder)

# %%
import os
import cv2

def extract_clips(input_folder, output_folder, clip_length=1200):
    # Create the output folder if it doesn't exist
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    # Loop through each file in the input folder
    for filename in os.listdir(input_folder):
        # Check if the file is a video
        if filename.endswith(('.mp4', '.avi', '.mov')):
            filepath = os.path.join(input_folder, filename)
            cap = cv2.VideoCapture(filepath)
            frame_count = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
            if frame_count < clip_length:
                print(f"Skipping {filename} - Insufficient frames")
                continue

            # Extract clips
            clip_count = frame_count // clip_length
            for i in range(clip_count):
                start_frame = i * clip_length
                end_frame = min(start_frame + clip_length, frame_count)

                cap.set(cv2.CAP_PROP_POS_FRAMES, start_frame)
                clip_frames = []
                for _ in range(start_frame, end_frame):
                    ret, frame = cap.read()
                    if ret:
                        clip_frames.append(frame)
                    else:
                        break

                # Save the clip
                output_filename = f"{filename}_clip_{i}.avi"
                output_filepath = os.path.join(output_folder, output_filename)
                out = cv2.VideoWriter(output_filepath, cv2.VideoWriter_fourcc(*'DIVX'), cap.get(cv2.CAP_PROP_FPS), (frame.shape[1], frame.shape[0]))
                for frame in clip_frames:
                    out.write(frame)
                out.release()

            cap.release()

# Example usage
input_folder = "/content/drive/MyDrive/ICIPE Research/Video_analytics/Videos/Negative"
output_folder = "/content/drive/MyDrive/ICIPE Research/Video_analytics/Videos/Negative_Data/1200_frames"
extract_clips(input_folder, output_folder)

# %%
import os
import cv2

def extract_clips(input_folder, output_folder, clip_length=1300):
    # Create the output folder if it doesn't exist
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    # Loop through each file in the input folder
    for filename in os.listdir(input_folder):
        # Check if the file is a video
        if filename.endswith(('.mp4', '.avi', '.mov')):
            filepath = os.path.join(input_folder, filename)
            cap = cv2.VideoCapture(filepath)
            frame_count = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
            if frame_count < clip_length:
                print(f"Skipping {filename} - Insufficient frames")
                continue

            # Extract clips
            clip_count = frame_count // clip_length
            for i in range(clip_count):
                start_frame = i * clip_length
                end_frame = min(start_frame + clip_length, frame_count)

                cap.set(cv2.CAP_PROP_POS_FRAMES, start_frame)
                clip_frames = []
                for _ in range(start_frame, end_frame):
                    ret, frame = cap.read()
                    if ret:
                        clip_frames.append(frame)
                    else:
                        break

                # Save the clip
                output_filename = f"{filename}_clip_{i}.avi"
                output_filepath = os.path.join(output_folder, output_filename)
                out = cv2.VideoWriter(output_filepath, cv2.VideoWriter_fourcc(*'DIVX'), cap.get(cv2.CAP_PROP_FPS), (frame.shape[1], frame.shape[0]))
                for frame in clip_frames:
                    out.write(frame)
                out.release()

            cap.release()

# Example usage
input_folder = "/content/drive/MyDrive/ICIPE Research/Video_analytics/Videos/Negative"
output_folder = "/content/drive/MyDrive/ICIPE Research/Video_analytics/Videos/Negative_Data/1300_frames"
extract_clips(input_folder, output_folder)

# %%
import os
import cv2

def extract_clips(input_folder, output_folder, clip_length=1400):
    # Create the output folder if it doesn't exist
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    # Loop through each file in the input folder
    for filename in os.listdir(input_folder):
        # Check if the file is a video
        if filename.endswith(('.mp4', '.avi', '.mov')):
            filepath = os.path.join(input_folder, filename)
            cap = cv2.VideoCapture(filepath)
            frame_count = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
            if frame_count < clip_length:
                print(f"Skipping {filename} - Insufficient frames")
                continue

            # Extract clips
            clip_count = frame_count // clip_length
            for i in range(clip_count):
                start_frame = i * clip_length
                end_frame = min(start_frame + clip_length, frame_count)

                cap.set(cv2.CAP_PROP_POS_FRAMES, start_frame)
                clip_frames = []
                for _ in range(start_frame, end_frame):
                    ret, frame = cap.read()
                    if ret:
                        clip_frames.append(frame)
                    else:
                        break

                # Save the clip
                output_filename = f"{filename}_clip_{i}.avi"
                output_filepath = os.path.join(output_folder, output_filename)
                out = cv2.VideoWriter(output_filepath, cv2.VideoWriter_fourcc(*'DIVX'), cap.get(cv2.CAP_PROP_FPS), (frame.shape[1], frame.shape[0]))
                for frame in clip_frames:
                    out.write(frame)
                out.release()

            cap.release()

# Example usage
input_folder = "/content/drive/MyDrive/ICIPE Research/Video_analytics/Videos/Negative"
output_folder = "/content/drive/MyDrive/ICIPE Research/Video_analytics/Videos/Negative_Data/1400_frames"
extract_clips(input_folder, output_folder)

# %%
import os
import cv2

def extract_clips(input_folder, output_folder, clip_length=1500):
    # Create the output folder if it doesn't exist
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    # Loop through each file in the input folder
    for filename in os.listdir(input_folder):
        # Check if the file is a video
        if filename.endswith(('.mp4', '.avi', '.mov')):
            filepath = os.path.join(input_folder, filename)
            cap = cv2.VideoCapture(filepath)
            frame_count = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
            if frame_count < clip_length:
                print(f"Skipping {filename} - Insufficient frames")
                continue

            # Extract clips
            clip_count = frame_count // clip_length
            for i in range(clip_count):
                start_frame = i * clip_length
                end_frame = min(start_frame + clip_length, frame_count)

                cap.set(cv2.CAP_PROP_POS_FRAMES, start_frame)
                clip_frames = []
                for _ in range(start_frame, end_frame):
                    ret, frame = cap.read()
                    if ret:
                        clip_frames.append(frame)
                    else:
                        break

                # Save the clip
                output_filename = f"{filename}_clip_{i}.avi"
                output_filepath = os.path.join(output_folder, output_filename)
                out = cv2.VideoWriter(output_filepath, cv2.VideoWriter_fourcc(*'DIVX'), cap.get(cv2.CAP_PROP_FPS), (frame.shape[1], frame.shape[0]))
                for frame in clip_frames:
                    out.write(frame)
                out.release()

            cap.release()

# Example usage
input_folder = "/content/drive/MyDrive/ICIPE Research/Video_analytics/Videos/Negative"
output_folder = "/content/drive/MyDrive/ICIPE Research/Video_analytics/Videos/Negative_Data/1500_frames"
extract_clips(input_folder, output_folder)
